# %%
import pandas as pd

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
pred_test=pd.read_csv('mobile_corrected.csv')

# %%
pred_test[['pred','itemid']].head()
# Out:
#    pred   itemid
# 0    31  2346660
# 1    31  2816338
# 2    32  2847602
# 3    32  3116949
# 4    33  3794648

# %%
train.set_index('itemid',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'itemid'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-99b3181bd0f4> in <module>
# ----> 1 train.set_index('itemid',inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3144                 names.append(None)
#    3145             else:
# -> 3146                 level = frame[col]._values
#    3147                 names.append(col)
#    3148                 if drop:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'itemid'

# %%
train_m=train.loc[pred_test.itemid,:]

# %%
train_m['pred']=pred_test.pred.values

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(train_m.Category,train_m.pred)
# Out:
# 0.82819273351005773

# %%
train_m['pred_true']=(train_m['Category']==train_m['pred'])

# %%
train_m.groupby('Category').pred_true.mean()
# Out:
# Category
# 31    0.895994
# 32    0.902201
# 33    0.939834
# 34    0.819633
# 35    0.557045
# 36    0.927184
# 37    0.859031
# 38    0.933050
# 39    0.899281
# 40    0.676923
# 41    0.926204
# 42    0.922381
# 43    0.879577
# 44    0.902174
# 45    0.904328
# 46    0.941606
# 47    0.814815
# 48    0.903614
# 49    0.443478
# 50    0.892857
# 51    0.814815
# 52    0.565217
# 53    0.642857
# 54    0.783333
# 55    0.933333
# 56    0.558824
# 57    0.000000
# Name: pred_true, dtype: float64

# %%
df_cat=pd.read_json('categories.json')

# %%
cat_m=df_cat['Mobile'].dropna()

# %%
cat=cat_m

# %%
cat_df=pd.DataFrame({'index':cat.values.astype('int'),'name':cat_m.index})
cat_df.set_index('index',inplace=True)

# %%
train_m['Category_name']=train_m['Category'].map(cat_df['name'])

# %%
train_m.head()
# Out:
#                                                         title  Category  \
# itemid
# 1058517290             xiaomi mi a1 garansi resmi 1 tahun tam        34
# 1195506745  promo discon samsung galaxy s7 flat sein garan...        35
# 1833821649   samsung galaxy a6 plus 2018 new garansi nasional        35
# 291297752                                    xiaomi redmi mi5        34
# 1812460647                           monggo diorder iphone 6s        31
#
#                                                    image_path  pred  \
# itemid
# 1058517290  mobile_image/3912586cdf51144db783b2bac1ee4d3f.jpg    34
# 1195506745  mobile_image/bb327fec3989b18f714deb3c07203fb8.jpg    35
# 1833821649  mobile_image/8959112348969556df29f24d06ecff8f.jpg    32
# 291297752   mobile_image/8733bba77a727e4771d51b5a8b48c8a5.jpg    34
# 1812460647  mobile_image/af7047829e497014daa5c2b4914a0fb4.jpg    31
#
#             pred_true           Category_name
# itemid
# 1058517290       True                  Xiaomi
# 1195506745       True  Others Mobile & Tablet
# 1833821649      False  Others Mobile & Tablet
# 291297752        True                  Xiaomi
# 1812460647       True                  Iphone

# %%
train_m.groupby('Category_name').pred_true.mean()
# Out:
# Category_name
# Advan                     0.904328
# Alcatel                   0.933333
# Asus                      0.879577
# Blackberry                0.927184
# Brandcode                 0.899281
# Evercoss                  0.902174
# Honor                     0.783333
# Huawei                    0.814815
# Icherry                   0.565217
# Infinix                   0.676923
# Iphone                    0.895994
# Lenovo                    0.859031
# Maxtron                   0.558824
# Mito                      0.941606
# Motorola                  0.443478
# Nokia                     0.933050
# Oppo                      0.926204
# Others Mobile & Tablet    0.557045
# Realme                    0.814815
# SPC                       0.000000
# Samsung                   0.902201
# Sharp                     0.903614
# Smartfren                 0.642857
# Sony                      0.939834
# Strawberry                0.892857
# Vivo                      0.922381
# Xiaomi                    0.819633
# Name: pred_true, dtype: float64

# %%
# Let's check iphone

# %%
from IPython.core.display import Image, display

# %%
train['Group']=train['image_path'].map(lambda x: x[:7])
test['Group']=test['image_path'].map(lambda x: x[:7])

# %%
false_iphone=train_m[(train_m.Category_name=='Iphone')&(train_m.pred_true==False)]

# %%
false_iphone.image_path.iloc[1]
# Out:
# 'mobile_image/8178859a9bf0f5f2869d3de6b336e8bb.jpg'

# %%
train[train.Group=='mobile_'].image_path.iloc[0]
# Out:
# 'mobile_image/a9c8f0fdd6587deed197634066cf7eee.jpg'

# %%
import matplotlib.pylab as plt

# %%
img=plt.imread(false_iphone.image_path.iloc[1])
plt.imshow(img)

# %%
def show_im(df_train):
    plt.figure(figsize=(20,20))
    df=df_train.sample(n=9)
    for i in range(9):
        y=331+i
        plt.subplot(y)
        img=plt.imread(df.image_path.iloc[i])
        plt.imshow(img)
        if len(false_iphone.title.iloc[i])>40:
            plt.text(0,-40,df.title.iloc[i][:40],fontsize=16)
            plt.text(0,-10,df.title.iloc[i][40:],fontsize=16)
        else:
            plt.text(0,-10,df.title.iloc[i],fontsize=16)

# %%
show_im(false_iphone)

# %%
train[train.Group=='mobile_'].loc[506285]
# Out:
# itemid                                                  2346660
# title         apple iphone 4s back glass spare part original...
# Category                                                     31
# image_path    mobile_image/a9c8f0fdd6587deed197634066cf7eee.jpg
# Group                                                   mobile_
# Name: 506285, dtype: object

# %%
show_image(train[train.Group=='mobile_'].loc[506285])
# Out:
# apple iphone 4s back glass spare part original replacement putih
